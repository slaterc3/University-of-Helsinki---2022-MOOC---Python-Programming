# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Write your solution here
def no_shouting(lst):
    return [x for x in lst if not x.isupper()]
    # lower = []
    # for word in lst:
    #     if not word.isupper():
    #         lower.append(word)
    # return lower

# print("XYZ".isupper())
# my_list = ["ABC", "def", "UPPER", "ANOTHERUPPER", "lower", "another lower", "Capitalized"]
# pruned = no_shouting(my_list)
# print(pruned)
if __name__ == "__main__":
    # pass
    my_list = ["ABC", "def", "UPPER", 
    "ANOTHERUPPER", "lower", "another lower", 
    "Capitalized"]
    pruned = no_shouting(my_list)
    print(pruned)
# Out:
# ['def', 'lower', 'another lower', 'Capitalized']
