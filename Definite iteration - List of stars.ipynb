# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Write your solution here
def list_of_stars(lst):
    for num in lst:
        print(num * '*')

# %%
list_of_stars([3, 7, 1, 1, 2])
# Out:
# ***
# *******
# *
# *
# **
