# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def create_tuple(x:int,y:int,z:int):
    tup = [x, y, z]
    tup = sorted(tup)
    tup = tuple(tup)
    return tup[0], tup[2], (sum(tup))

# %%
create_tuple(5, 3, -1)
# Out:
# (-1, 5, 7)
