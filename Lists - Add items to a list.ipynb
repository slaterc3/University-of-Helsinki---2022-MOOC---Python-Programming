# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Write your solution here
num_items = int(input("How many items: "))
lst = [x for x in range(num_items)]
i = 0

while i < num_items:
    lst[i] = int(input(f"Item {i + 1}: "))
    i += 1
print(lst)
# Out:
# How many items: 3
# Item 1: 10
# Item 2: 250
# Item 3: 34
# [10, 250, 34]
