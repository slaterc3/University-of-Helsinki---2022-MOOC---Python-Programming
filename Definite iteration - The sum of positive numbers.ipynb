# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Write your solution here
def sum_of_positives(lst):
    total = 0
    for num in lst:
        if num > 0:
            total += num
    return total

if __name__ == "__main__":

    my_lst = [1, -2, 3, -4, 5]

    res = sum_of_positives(my_lst)
    print(f"The result is {res}")
# Out:
# The result is 9
