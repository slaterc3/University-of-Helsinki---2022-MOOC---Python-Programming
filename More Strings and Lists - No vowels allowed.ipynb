# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Write your solution here
def no_vowels(user_str):
    new_str = ''
    for ch in user_str:
        if ch not in ['a','e','i','o','u']:
            new_str += ch
    return new_str

if __name__ == "__main__":
    my_string = 'this is an example'
    print(no_vowels(my_string))
# Out:
# ths s n xmpl
