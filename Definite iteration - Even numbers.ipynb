# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Write your solution here
def even_numbers(lst):
    return [x for x in lst if x % 2 == 0]


if __name__ == "__main__":
    my_lst = [1,2,3,4,5]
    new_lst = even_numbers(my_lst)
    print(f"original {my_lst}")
    print(f"new {new_lst}")
# Out:
# original [1, 2, 3, 4, 5]
# new [2, 4]
